# %%
# !pip install pydub
# Out:
# Requirement already satisfied: pydub in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (0.25.1)

# %%
# !pip install speechrecognition
# Out:
# Requirement already satisfied: speechrecognition in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (3.14.3)
# Requirement already satisfied: typing-extensions in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (from speechrecognition) (4.14.0)
# Requirement already satisfied: standard-aifc in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (from speechrecognition) (3.13.0)
# Requirement already satisfied: audioop-lts in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (from speechrecognition) (0.2.1)
# Requirement already satisfied: standard-chunk in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (from standard-aifc->speechrecognition) (3.13.0)

# %%
# !pip install gtts
# Out:
# Requirement already satisfied: gtts in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (2.5.4)
# Requirement already satisfied: requests<3,>=2.27 in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (from gtts) (2.32.4)
# Requirement already satisfied: click<8.2,>=7.1 in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (from gtts) (8.1.8)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (from requests<3,>=2.27->gtts) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (from requests<3,>=2.27->gtts) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (from requests<3,>=2.27->gtts) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/syssoni/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages (from requests<3,>=2.27->gtts) (2025.6.15)

# %% [markdown]
# # Import necessary libraries

# %%
import moviepy.editor as mp
import speech_recognition as sr
from gtts import gTTS
from transformers import pipeline
import os
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.

# %%
def mp4_to_wav(mp4_file, wav_file):
    # Load video file
    video = mp.VideoFileClip(mp4_file)

    # Extract audio and write to WAV file directly
    audio = video.audio
    audio.write_audiofile(wav_file, codec='pcm_s16le')

# %%
def speech_to_text(wav_file):
    # Initialize recognizer
    recognizer = sr.Recognizer()

    # Load audio file
    with sr.AudioFile(wav_file) as source:
        audio_data = recognizer.record(source)
        text = recognizer.recognize_google(audio_data)

    return text

# %%
def summarize_text(text):
    # Initialize the summarization pipeline
    summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

    # Perform summarization
    summary = summarizer(text, max_length=130, min_length=30, do_sample=False)

    return summary[0]['summary_text']

# %%
def analyze_sentiment(text):
    # Initialize the sentiment analysis pipeline with a more robust model
    sentiment_analyzer = pipeline("sentiment-analysis", model="distilbert-base-uncased-finetuned-sst-2-english")

    # Perform sentiment analysis
    sentiment = sentiment_analyzer(text)

    return sentiment[0]['label'], sentiment[0]['score']

# %%
def classify_working_environment(sentiment_label, sentiment_score):
    if sentiment_label == 'NEGATIVE' and sentiment_score > 0.75:
        return "Harsh Working Environment"
    elif sentiment_label == 'POSITIVE' and sentiment_score > 0.75:
        return "Good Working Environment"
    else:
        return "Mediocre Working Environment"

# %%
def text_to_speech(text, tts_file):
    tts = gTTS(text)
    tts.save(tts_file)

# %%
def process_video(mp4_file, wav_file, tts_file):
    # Convert MP4 to WAV
    mp4_to_wav(mp4_file, wav_file)

    # Perform Speech-to-Text
    text = speech_to_text(wav_file)

    # Summarize the text
    summarized_text = summarize_text(text)

    # Perform Text-to-Speech
    text_to_speech(summarized_text, tts_file)

    # Perform Sentiment Analysis
    sentiment_label, sentiment_score = analyze_sentiment(summarized_text)

    # Classify Working Environment
    working_environment = classify_working_environment(sentiment_label, sentiment_score)

    return text, summarized_text, sentiment_label, sentiment_score, working_environment

# %%
# File paths (replace with your actual file paths)
mp4_file = "test_video_1.mp4"
wav_file = "output_audio.wav"
tts_file = "output_tts.mp3"

# Process the video
text, summarized_text, sentiment_label, sentiment_score, working_environment = process_video(mp4_file, wav_file, tts_file)

# Display results
print("Transcribed Text:")
print(text)

print("\nSummarized Text:")
print(summarized_text)

print("\nSentiment Analysis:")
print(f"Sentiment: {sentiment_label}")
print(f"Confidence: {sentiment_score:.2f}")

print("\nWorking Environment Classification:")
print(working_environment)
# Out:
# MoviePy - Writing audio in output_audio.wav
# MoviePy - Done.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 7
#       4 tts_file = "output_tts.mp3"
#       6 # Process the video
# ----> 7 text, summarized_text, sentiment_label, sentiment_score, working_environment = process_video(mp4_file, wav_file, tts_file)
#       9 # Display results
#      10 print("Transcribed Text:")
#
# Cell In[12], line 9, in process_video(mp4_file, wav_file, tts_file)
#       6 text = speech_to_text(wav_file)
#       8 # Summarize the text
# ----> 9 summarized_text = summarize_text(text)
#      11 # Perform Text-to-Speech
#      12 text_to_speech(summarized_text, tts_file)
#
# Cell In[8], line 3, in summarize_text(text)
#       1 def summarize_text(text):
#       2     # Initialize the summarization pipeline
# ----> 3     summarizer = pipeline("summarization", model="facebook/bart-large-cnn")
#       5     # Perform summarization
#       6     summary = summarizer(text, max_length=130, min_length=30, do_sample=False)
#
# File ~/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages/transformers/pipelines/__init__.py:942, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     940 if isinstance(model, str) or framework is None:
#     941     model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 942     framework, model = infer_framework_load_model(
#     943         adapter_path if adapter_path is not None else model,
#     944         model_classes=model_classes,
#     945         config=config,
#     946         framework=framework,
#     947         task=task,
#     948         **hub_kwargs,
#     949         **model_kwargs,
#     950     )
#     952 model_config = model.config
#     953 hub_kwargs["_commit_hash"] = model.config._commit_hash
#
# File ~/miniconda3/envs/meeting_sentiment_analysis/lib/python3.13/site-packages/transformers/pipelines/base.py:242, in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     216 """
#     217 Select framework (TensorFlow or PyTorch) to use from the `model` passed. Returns a tuple (framework, model).
#     218
#    (...)    239     `Tuple`: A tuple framework, model.
#     240 """
#     241 if not is_tf_available() and not is_torch_available():
# --> 242     raise RuntimeError(
#     243         "At least one of TensorFlow 2.0 or PyTorch should be installed. "
#     244         "To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ "
#     245         "To install PyTorch, read the instructions at https://pytorch.org/."
#     246     )
#     247 if isinstance(model, str):
#     248     model_kwargs["_from_pipeline"] = task
#
# RuntimeError: At least one of TensorFlow 2.0 or PyTorch should be installed. To install TensorFlow 2.0, read the instructions at https://www.tensorflow.org/install/ To install PyTorch, read the instructions at https://pytorch.org/.
